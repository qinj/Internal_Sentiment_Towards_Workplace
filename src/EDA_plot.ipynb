# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
nlp_df = pd.read_csv('../data/df_with_nlp.csv', index_col=0)
X = nlp_df
# X = X[['culture-values-stars', 'career-opportunities-stars',
#                        'comp-benefit-stars', 'senior-management-stars', 'helpful-count',
#                        'is_current_employee', 'year', 'quarter', 'amazon_earnings_this_quarter', 'timesteps', 'incomplete_review', 'pros_len', 'cons_len']]
y = pd.read_csv("../data/work-balance-stars.csv", header=None, index_col=0).values

# %%
# X['culture-values-stars'].values.shape
y = y.reshape(26428,)

# %%
X['y'] = y

# %%
X['pro-con-len-ratio']

# %%
sns.catplot(x="career-opportunities-stars", y="y", kind="box", data=X);

# %%
sns.catplot(x="culture-values-stars", y="y", kind="box", data=X);

# %%
sns.catplot(x="y", y="pro-con-len-ratio", data=X);

# %%
sns.catplot(x="y", y="cons_len", data=X);

# %%
X['culture-values-stars'].unique()
# Out:
# array([5., 3., 2., 4., 1.])

# %%
plt.hist(X['comp-benefit-stars'], bins=)
# Out:
# (array([1312., 2231., 8302., 7842., 6741.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <a list of 5 Patch objects>)
